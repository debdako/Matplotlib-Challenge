# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %%
# Importing Dataset1
dataset1 = pd.read_csv("Provisional_COVID-19_Deaths__Distribution_of_Deaths_by_Race_and_Hispanic_Origin.csv")
dataset1.head(5)
# Out:
#    Data as of  Start Date    End Date  Year  Month    Group          State  \
# 0  08/03/2022  01/01/2021  12/31/2021  2021    NaN  By Year  United States
# 1  08/03/2022  01/01/2021  12/31/2021  2021    NaN  By Year  United States
# 2  08/03/2022  01/01/2021  12/31/2021  2021    NaN  By Year  United States
# 3  08/03/2022  01/01/2021  12/31/2021  2021    NaN  By Year  United States
# 4  08/03/2022  01/01/2021  12/31/2021  2021    NaN  By Year        Alabama
#
#                                    Indicator  Non-Hispanic White  \
# 0                   Count of COVID-19 deaths            304824.0
# 1        Distribution of COVID-19 deaths (%)                65.8
# 2  Unweighted distribution of population (%)                59.7
# 3    Weighted distribution of population (%)                40.5
# 4                   Count of COVID-19 deaths              6896.0
#
#    Non-Hispanic Black or African American  \
# 0                                 62036.0
# 1                                    13.4
# 2                                    12.6
# 3                                    12.9
# 4                                  2524.0
#
#    Non-Hispanic American Indian or Alaska Native  Non-Hispanic Asian  \
# 0                                         5056.0             13787.0
# 1                                            1.1                 3.0
# 2                                            0.7                 5.9
# 3                                            0.4                 9.4
# 4                                           24.0                48.0
#
#    Non-Hispanic Native Hawaiian or Other Pacific Islander  \
# 0                                             1182.0
# 1                                                0.3
# 2                                                0.2
# 3                                                0.2
# 4                                                NaN
#
#    Non Hispanic more than one race  Hispanic or Latino  \
# 0                           2023.0             73478.0
# 1                              0.4                15.9
# 2                              2.3                18.6
# 3                              2.2                34.3
# 4                             17.0               198.0
#
#                                             Footnote
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  One or more data cells have counts between 1-9...

# %%
# Returns tuple of shape (Rows, columns)
print(dataset1.shape)
  
# Returns size of dataframe
print(dataset1.size)
# Out:
# (212, 16)
# 3392

# %%
# Information about Dataset1
# return concise summary of dataframe
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 16 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Data as of                                              212 non-null    object
#  1   Start Date                                              212 non-null    object
#  2   End Date                                                212 non-null    object
#  3   Year                                                    212 non-null    int64
#  4   Month                                                   0 non-null      float64
#  5   Group                                                   212 non-null    object
#  6   State                                                   212 non-null    object
#  7   Indicator                                               212 non-null    object
#  8   Non-Hispanic White                                      212 non-null    float64
#  9   Non-Hispanic Black or African American                  196 non-null    float64
#  10  Non-Hispanic American Indian or Alaska Native           186 non-null    float64
#  11  Non-Hispanic Asian                                      200 non-null    float64
#  12  Non-Hispanic Native Hawaiian or Other Pacific Islander  160 non-null    float64
#  13  Non Hispanic more than one race                         178 non-null    float64
#  14  Hispanic or Latino                                      208 non-null    float64
#  15  Footnote                                                72 non-null     object
# dtypes: float64(8), int64(1), object(7)
# memory usage: 26.6+ KB

# %%
dataset1.describe()
# Out:
#          Year  Month  Non-Hispanic White  \
# count   212.0    0.0          212.000000
# mean   2021.0    NaN         2925.674528
# std       0.0    NaN        21165.095605
# min    2021.0    NaN           11.200000
# 25%    2021.0    NaN           61.025000
# 50%    2021.0    NaN           77.900000
# 75%    2021.0    NaN           96.425000
# max    2021.0    NaN       304824.000000
#
#        Non-Hispanic Black or African American  \
# count                              196.000000
# mean                               642.994388
# std                               4507.633501
# min                                  0.400000
# 25%                                  5.575000
# 50%                                 14.000000
# 75%                                 36.875000
# max                              62036.000000
#
#        Non-Hispanic American Indian or Alaska Native  Non-Hispanic Asian  \
# count                                     186.000000          200.000000
# mean                                       55.367742          141.203000
# std                                       384.016454         1047.497939
# min                                         0.000000            0.300000
# 25%                                         0.200000            2.000000
# 50%                                         0.700000            4.250000
# 75%                                         8.425000           15.000000
# max                                      5056.000000        13787.000000
#
#        Non-Hispanic Native Hawaiian or Other Pacific Islander  \
# count                                         160.000000
# mean                                           14.677500
# std                                            98.992891
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.100000
# 75%                                             0.400000
# max                                          1182.000000
#
#        Non Hispanic more than one race  Hispanic or Latino
# count                       178.000000          208.000000
# mean                         24.111236          715.752885
# std                         155.808817         5476.847099
# min                           0.000000            0.700000
# 25%                           1.600000            5.775000
# 50%                           2.200000           11.950000
# 75%                           3.850000           40.800000
# max                        2023.000000        73478.000000

# %%
dataset1.isnull().sum()
# Out:
# Data as of                                                  0
# Start Date                                                  0
# End Date                                                    0
# Year                                                        0
# Month                                                     212
# Group                                                       0
# State                                                       0
# Indicator                                                   0
# Non-Hispanic White                                          0
# Non-Hispanic Black or African American                     16
# Non-Hispanic American Indian or Alaska Native              26
# Non-Hispanic Asian                                         12
# Non-Hispanic Native Hawaiian or Other Pacific Islander     52
# Non Hispanic more than one race                            34
# Hispanic or Latino                                          4
# Footnote                                                  140
# dtype: int64

# %%
dataset1.dropna(inplace = True)
dataset1.shape
# Out:
# (0, 16)

# %%
dataset1.isnull().sum()
# Out:
# Data as of                                                0.0
# Start Date                                                0.0
# End Date                                                  0.0
# Year                                                      0.0
# Month                                                     0.0
# Group                                                     0.0
# State                                                     0.0
# Indicator                                                 0.0
# Non-Hispanic White                                        0.0
# Non-Hispanic Black or African American                    0.0
# Non-Hispanic American Indian or Alaska Native             0.0
# Non-Hispanic Asian                                        0.0
# Non-Hispanic Native Hawaiian or Other Pacific Islander    0.0
# Non Hispanic more than one race                           0.0
# Hispanic or Latino                                        0.0
# Footnote                                                  0.0
# dtype: float64

# %%
# Columns labels of a Dataset1
dataset1.columns
# Out:
# Index(['Data as of', 'Start Date', 'End Date', 'Year', 'Month', 'Group',
#        'State', 'Indicator', 'Non-Hispanic White',
#        'Non-Hispanic Black or African American',
#        'Non-Hispanic American Indian or Alaska Native', 'Non-Hispanic Asian',
#        'Non-Hispanic Native Hawaiian or Other Pacific Islander',
#        'Non Hispanic more than one race', 'Hispanic or Latino', 'Footnote'],
#       dtype='object')

# %%
# Drop Month, Group, Indicator, and Footnote rows from dataset1
  
dataset1.drop(['Month', 'Group', 'Indicator','Footnote'], 
              axis=1, inplace=True)
  
# Select random set of values from dataset1
dataset1.sample(5)

# %%
df.describe()
# Out:
#          Year  Month  Non-Hispanic White  \
# count   212.0    0.0          212.000000
# mean   2021.0    NaN         2925.674528
# std       0.0    NaN        21165.095605
# min    2021.0    NaN           11.200000
# 25%    2021.0    NaN           61.025000
# 50%    2021.0    NaN           77.900000
# 75%    2021.0    NaN           96.425000
# max    2021.0    NaN       304824.000000
#
#        Non-Hispanic Black or African American  \
# count                              196.000000
# mean                               642.994388
# std                               4507.633501
# min                                  0.400000
# 25%                                  5.575000
# 50%                                 14.000000
# 75%                                 36.875000
# max                              62036.000000
#
#        Non-Hispanic American Indian or Alaska Native  Non-Hispanic Asian  \
# count                                     186.000000          200.000000
# mean                                       55.367742          141.203000
# std                                       384.016454         1047.497939
# min                                         0.000000            0.300000
# 25%                                         0.200000            2.000000
# 50%                                         0.700000            4.250000
# 75%                                         8.425000           15.000000
# max                                      5056.000000        13787.000000
#
#        Non-Hispanic Native Hawaiian or Other Pacific Islander  \
# count                                         160.000000
# mean                                           14.677500
# std                                            98.992891
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.100000
# 75%                                             0.400000
# max                                          1182.000000
#
#        Non Hispanic more than one race  Hispanic or Latino
# count                       178.000000          208.000000
# mean                         24.111236          715.752885
# std                         155.808817         5476.847099
# min                           0.000000            0.700000
# 25%                           1.600000            5.775000
# 50%                           2.200000           11.950000
# 75%                           3.850000           40.800000
# max                        2023.000000        73478.000000

# %%
dataset1.dropna(inplace = True)
dataset1.shape
# Out:
# (0, 7)

# %%
# defining labels
ethnicity = ['Non-Hispanic White', 'Non-Hispanic Black or African American','Non-Hispanic American Indian or Alaska Native', 'Non-Hispanic Asian','Non-Hispanic Native Hawaiian or Other Pacific Islander', 'Hispanic or Latino']
# portion covered by each label
deaths = [65.8, 13.4, 1.1, 3.0, 0.3, 15.9]
  
# color for each label
colors = ['r', 'y', 'g', 'b','c','m']
  
# plotting the pie chart
fig = plt.figure(figsize =(12, 7))
plt.pie(deaths, labels = ethnicity, colors=colors, 
        startangle=90, shadow = True, explode = (None),
        radius = 1.2, autopct = '%1.1f%%')
plt.title("COVID 19 DEATH STATISTICS BY ETHNICITY", bbox={'facecolor':'0.8', 'pad':5})  
# showing the plot
plt.show()

# %%
# Importing Dataset2
dataset2 = pd.read_csv("race_ethnicity_of_people_fully_vaccinated.csv")
dataset2.head(5)
# Out:
#                                       Race_Ethnicity  \
# 0                                    Hispanic/Latino
# 1         American Indian/Alaska Native Non-Hispanic
# 2                                 Asian Non-Hispanic
# 3                                 Black Non-Hispanic
# 4  Native Hawaiian/Other Pacific Islander Non-His...
#
#    % People Fully Vaccinated  People_Fully_Vaccinated  % US Population  \
# 0                       19.8                 34579296             19.2
# 1                        0.9                  1498047              0.7
# 2                        6.8                 11829492              5.7
# 3                       10.1                 17689531             12.4
# 4                        0.3                   569662              0.3
#
#    % People completed vaccination in Last 14 Days  \
# 0                                            20.6
# 1                                             1.2
# 2                                             8.6
# 3                                            12.7
# 4                                             0.3
#
#    # People completed vaccination in Last 14 Days
# 0                                           51847
# 1                                            2926
# 2                                           21643
# 3                                           31909
# 4                                             789

# %%
# Returns tuple of shape (Rows, columns)
print(dataset2.shape)
  
# Returns size of dataframe
print(dataset2.size)
# Out:
# (7, 6)
# 42

# %%
# Information about Dataset1
# return concise summary of dataframe
dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Race_Ethnicity                                  7 non-null      object
#  1   % People Fully Vaccinated                       7 non-null      float64
#  2   People_Fully_Vaccinated                         7 non-null      int64
#  3   % US Population                                 7 non-null      float64
#  4   % People completed vaccination in Last 14 Days  7 non-null      float64
#  5   # People completed vaccination in Last 14 Days  7 non-null      int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 464.0+ bytes

# %%
dataset2.describe()
# Out:
#        % People Fully Vaccinated  People_Fully_Vaccinated  % US Population  \
# count                   7.000000             7.000000e+00         7.000000
# mean                   13.757143             2.400238e+07        14.271429
# std                    19.869898             3.467396e+07        21.067171
# min                     0.300000             5.696620e+05         0.300000
# 25%                     1.600000             2.736773e+06         1.450000
# 50%                     6.800000             1.182949e+07         5.700000
# 75%                    14.950000             2.613441e+07        15.800000
# max                    56.100000             9.787515e+07        59.400000
#
#        % People completed vaccination in Last 14 Days  \
# count                                        7.000000
# mean                                        13.728571
# std                                         17.420841
# min                                          0.300000
# 25%                                          2.100000
# 50%                                          8.600000
# 75%                                         16.650000
# max                                         49.700000
#
#        # People completed vaccination in Last 14 Days
# count                                        7.000000
# mean                                     34526.714286
# std                                      43818.598124
# min                                        789.000000
# 25%                                       5252.000000
# 50%                                      21643.000000
# 75%                                      41878.000000
# max                                     124995.000000

# %%
dataset2.isnull().sum()
# Out:
# Race_Ethnicity                                    0
# % People Fully Vaccinated                         0
# People_Fully_Vaccinated                           0
# % US Population                                   0
# % People completed vaccination in Last 14 Days    0
# # People completed vaccination in Last 14 Days    0
# dtype: int64

# %%
# Columns labels of a Dataset2
dataset2.columns
# Out:
# Index(['Race_Ethnicity', '% People Fully Vaccinated',
#        'People_Fully_Vaccinated', '% US Population',
#        '% People completed vaccination in Last 14 Days',
#        '# People completed vaccination in Last 14 Days'],
#       dtype='object')

# %%
# Drop % People completed vaccination in Last 14 Days and # People completed vaccination in Last 14 Days rows from dataset2
  
dataset2.drop(['% People completed vaccination in Last 14 Days', '# People completed vaccination in Last 14 Days'], 
              axis=1, inplace=True)
  
# Select random set of values from dataset1
dataset2.sample(5)
# Out:
#                                       Race_Ethnicity  \
# 4  Native Hawaiian/Other Pacific Islander Non-His...
# 1         American Indian/Alaska Native Non-Hispanic
# 5                                 White Non-Hispanic
# 0                                    Hispanic/Latino
# 3                                 Black Non-Hispanic
#
#    % People Fully Vaccinated  People_Fully_Vaccinated  % US Population
# 4                        0.3                   569662              0.3
# 1                        0.9                  1498047              0.7
# 5                       56.1                 97875147             59.4
# 0                       19.8                 34579296             19.2
# 3                       10.1                 17689531             12.4

# %%
# Columns labels of a Dataset2
dataset2.columns
# Out:
# Index(['Race_Ethnicity', '% People Fully Vaccinated',
#        'People_Fully_Vaccinated', '% US Population'],
#       dtype='object')

# %%
#importing Data
dataset2 = pd.read_csv("race_ethnicity_of_people_fully_vaccinated.csv")
df = pd.DataFrame(dataset2)

X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 1])

# Plot the data using bar() method
fig, ax = plt.subplots(figsize =(16, 12))
plt.barh(X, Y, color='g')
plt.title("VACCINATED PEOPLE BY ETHNICITY")
plt.xlabel("% People Fully Vaccinated")
plt.ylabel("Race_Ethnicity")

# Show the plot
plt.show()
