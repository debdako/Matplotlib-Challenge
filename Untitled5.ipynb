# %%
# libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import csv

df = pd.read_csv('race_ethnicity_of_people_fully_vaccinated.csv')
df.head()
# Out:
#                                       Race/Ethnicity  \
# 0                                    Hispanic/Latino
# 1         American Indian/Alaska Native Non-Hispanic
# 2                                 Asian Non-Hispanic
# 3                                 Black Non-Hispanic
# 4  Native Hawaiian/Other Pacific Islander Non-His...
#
#    % People Fully Vaccinated  # People Fully Vaccinated  % US Population  \
# 0                       19.8                   34579296             19.2
# 1                        0.9                    1498047              0.7
# 2                        6.8                   11829492              5.7
# 3                       10.1                   17689531             12.4
# 4                        0.3                     569662              0.3
#
#    % People completed vaccination in Last 14 Days  \
# 0                                            20.6
# 1                                             1.2
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                                       Race/Ethnicity  \
# 0                                    Hispanic/Latino
# 1         American Indian/Alaska Native Non-Hispanic
# 2                                 Asian Non-Hispanic
# 3                                 Black Non-Hispanic
# 4  Native Hawaiian/Other Pacific Islander Non-His...
# 5                                 White Non-Hispanic
# 6                              Multiple Non-Hispanic
#
#    % People Fully Vaccinated  # People Fully Vaccinated  % US Population  \
# 0                       19.8                   34579296             19.2
# 1                        0.9                    1498047              0.7
# 2                        6.8                   11829492              5.7
# 3                       10.1                   17689531             12.4
# 4                        0.3                     569662              0.3
# ...

# %%
df.isnull().sum()
# Out:
# Race/Ethnicity                                    0
# % People Fully Vaccinated                         0
# # People Fully Vaccinated                         0
# % US Population                                   0
# % People completed vaccination in Last 14 Days    0
# # People completed vaccination in Last 14 Days    0
# dtype: int64

# %%
# Data cleaning
How many missing Data are in the Data set?

# %%
# Using the Fillna methode to fill it

# %%
df.fillna(0,inplace = True)
df.head()
# Out:
#         Location  Overall  White  Black  Hispanic  Asian or Pacific Islander  \
# 0  United States    835.4  831.2    0.0     723.6                      470.5
# 1        Alabama      0.0    0.0    0.0     460.2                      455.9
# 2         Alaska    769.4  680.6  852.1     487.1                      551.9
# 3        Arizona    800.3  749.6  973.2     841.7                      480.5
# 4       Arkansas      0.0  992.6    0.0     523.5                      670.3
#
#   American Indian or Alaska Native
# 0                                0
# 1                            319.8
# 2                                0
# 3                                0
# 4                            305.4

# %%
df.isnull().sum()
# Out:
# Location                            0
# Overall                             0
# White                               0
# Black                               0
# Hispanic                            0
# Asian or Pacific Islander           0
# American Indian or Alaska Native    0
# dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                 Location  Overall  White  Black  Hispanic  \
# 0          United States    835.4  831.2    0.0     723.6
# 1                Alabama      0.0    0.0    0.0     460.2
# 2                 Alaska    769.4  680.6  852.1     487.1
# 3                Arizona    800.3  749.6  973.2     841.7
# 4               Arkansas      0.0  992.6    0.0     523.5
# 5             California    705.3  733.5    0.0     709.8
# 6               Colorado    754.2  724.0    0.0     867.9
# 7            Connecticut    769.1  759.1  984.1     701.7
# 8               Delaware    835.9  834.3  986.5     552.8
# 9   District of Columbia    862.3  390.0    0.0     624.0
# 10               Florida    735.7  765.3  938.6     609.1
# 11               Georgia    902.1  895.2    0.0     518.9
# 12                Hawaii    588.0  595.7  650.6       0.0
# 13                 Idaho    784.4  793.6  588.2     641.2
# 14              Illinois    850.7  820.2    0.0     688.3
# ...

# %%
import pandas as pd
df.describe()
# Out:
#           Overall       White       Black    Hispanic  \
# count   52.000000   52.000000   52.000000   52.000000
# mean   693.265385  748.532692  299.359615  597.775000
# std    306.322638  240.221882  393.856721  164.143667
# min      0.000000    0.000000    0.000000    0.000000
# 25%    737.775000  751.850000    0.000000  521.000000
# 50%    803.450000  799.450000    0.000000  602.350000
# 75%    854.075000  851.875000  699.000000  703.725000
# max    967.100000  999.700000  986.500000  909.300000
#
#        Asian or Pacific Islander
# count                  52.000000
# mean                  485.671154
# std                    89.176330
# min                   310.700000
# 25%                   433.700000
# 50%                   473.200000
# 75%                   528.975000
# max                   702.100000

# %%
df.describe()
# Out:
#        % People Fully Vaccinated  # People Fully Vaccinated  % US Population  \
# count                   7.000000               7.000000e+00         7.000000
# mean                   13.757143               2.400238e+07        14.271429
# std                    19.869898               3.467396e+07        21.067171
# min                     0.300000               5.696620e+05         0.300000
# 25%                     1.600000               2.736773e+06         1.450000
# 50%                     6.800000               1.182949e+07         5.700000
# 75%                    14.950000               2.613441e+07        15.800000
# max                    56.100000               9.787515e+07        59.400000
#
#        % People completed vaccination in Last 14 Days  \
# count                                        7.000000
# mean                                        13.728571
# std                                         17.420841
# min                                          0.300000
# ...

# %%
import matplotlib.pyplot as plt
df = pd.read_csv('race_ethnicity_of_people_fully_vaccinated.csv')
plt.bar('Race/Ethnicity')
plt.title()
plt.xlabel('Race/Ethnicity')
plt.ylabel('People_fully_vaccinated)
plt.show()
# Out:
#   Input In [45]
#     plt.ylabel('People_fully_vaccinated)
#                                         ^
# SyntaxError: EOL while scanning string literal

# %%
fig = px.bar(countries_vaccination_df.head(20), x='country', y='total_vaccinations',
            hover_data=['total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated'], color='country')
fig.update_layout(template='plotly_dark')
# Alternative way for doing background dark
# fig.update_layout(plot_bgcolor = "black")
fig.update_layout(title="Top 20 Countries in view of Total Vaccinations",
                 xaxis_title= "Country Name",
                 yaxis_title= "Population")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 fig = px.bar(countries_vaccination_df.head(20), x='country', y='total_vaccinations',
#       2             hover_data=['total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated'], color='country')
#       3 fig.update_layout(template='plotly_dark')
#       4 # Alternative way for doing background dark
#       5 # fig.update_layout(plot_bgcolor = "black")
#
# NameError: name 'px' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
df = pd.read_csv('race_ethnicity_of_people_fully_vaccinated.csv')
People_Fully_Vaccinated= df.dropna()
# This cleans the data or removes cells with null values
People_Fully_Vaccinated
# Out:
#                                       Race_Ethnicity  \
# 0                                    Hispanic/Latino
# 1         American Indian/Alaska Native Non-Hispanic
# 2                                 Asian Non-Hispanic
# 3                                 Black Non-Hispanic
# 4  Native Hawaiian/Other Pacific Islander Non-His...
# 5                                 White Non-Hispanic
# 6                              Multiple Non-Hispanic
#
#    % People Fully Vaccinated  People_Fully_Vaccinated  % US Population  \
# 0                       19.8                 34579296             19.2
# 1                        0.9                  1498047              0.7
# 2                        6.8                 11829492              5.7
# 3                       10.1                 17689531             12.4
# 4                        0.3                   569662              0.3
# 5                       56.1                 97875147             59.4
# ...

# %%
sns.set_theme
ax = sns.countplot(x="Race_Ethnicity", data=People_Fully_Vaccinated)

# %%
Number_of_Deaths = pd.read_csv('race_ethnicity_of_people_fully_vaccinated.csv', index_col=0)
Number_of_Deaths
# Out:
#                                                     % People Fully Vaccinated  \
# Race_Ethnicity
# Hispanic/Latino                                                          19.8
# American Indian/Alaska Native Non-Hispanic                                0.9
# Asian Non-Hispanic                                                        6.8
# Black Non-Hispanic                                                       10.1
# Native Hawaiian/Other Pacific Islander Non-Hisp...                        0.3
# White Non-Hispanic                                                       56.1
# Multiple Non-Hispanic                                                     2.3
#
#                                                     People_Fully_Vaccinated  \
# Race_Ethnicity
# Hispanic/Latino                                                    34579296
# American Indian/Alaska Native Non-Hispanic                          1498047
# Asian Non-Hispanic                                                 11829492
# ...

# %%
for col in Number_of_Deaths.columns:
    print(col)
# Out:
# % People Fully Vaccinated
# People_Fully_Vaccinated
# % US Population
# % People completed vaccination in Last 14 Days
# # People completed vaccination in Last 14 Days

# %%
sns.set(style='white')

#create sbar chart
picture = Number_of_Deaths.plot(kind='bar', color=['orange', 'yellow', 'green', 'blue', 'purple','cyan'])
picture
# Out:
# <AxesSubplot:xlabel='Race_Ethnicity'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
Vaccinated_df = sns.load_dataset("Vaccinated")
Vaccinated_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [66], in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
# ----> 3 Vaccinated_df = sns.load_dataset("Vaccinated")
#       4 Vaccinated_df
#
# File ~\anaconda3\lib\site-packages\seaborn\utils.py:595, in load_dataset(name, cache, data_home, **kws)
#     593 if not os.path.exists(cache_path):
#     594     if name not in get_dataset_names():
# --> 595         raise ValueError(f"'{name}' is not one of the example datasets.")
#     596     urlretrieve(url, cache_path)
#     597 full_path = cache_path
#
# ValueError: 'Vaccinated' is not one of the example datasets.

# %%
import matplotlib.pyplot as plt
   
Race_Ethnicity = ['White','Black','Hispanic','Asian or Pacific Islander','American Indian or Alaska Native']
People_Fully_Vaccinated= [34579296,1498047,11829492,17689531,569662,97875147,3975499]                             


df = pd.read_csv('race_ethnicity_of_people_fully_vaccinated.csv')

New_Colors = ['purple','brown','green','yellow','teal']
plt.bar(Race_Ethnicity,People_Fully_Vaccinated, color=New_Colors)
plt.title('Country Vs GDP Per Capita', fontsize=14)
plt.xlabel('Race_Ethnicity', fontsize=14)
plt.ylabel('People_Fully_Vaccinated,', fontsize=14)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [69], in <cell line: 10>()
#       7 df = pd.read_csv('race_ethnicity_of_people_fully_vaccinated.csv')
#       9 New_Colors = ['purple','brown','green','yellow','teal']
# ---> 10 plt.bar(Race_Ethnicity,People_Fully_Vaccinated, color=New_Colors)
#      11 plt.title('Country Vs GDP Per Capita', fontsize=14)
#      12 plt.xlabel('Race_Ethnicity', fontsize=14)
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2387, in bar(x, height, width, bottom, align, data, **kwargs)
#    2383 @_copy_docstring_and_deprecators(Axes.bar)
#    2384 def bar(
#    2385         x, height, width=0.8, bottom=None, *, align='center',
#    2386         data=None, **kwargs):
# -> 2387     return gca().bar(
#    2388         x, height, width=width, bottom=bottom, align=align,
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

Data = {'Race_Ethnicity': ['White','Black','Hispanic','Asian or Pacific Islander','American Indian or Alaska Native'],
        'People_Fully_Vaccinated': [34579296,1498047,11829492,17689531,569662,97875147,3975499]  
       }
df = pd.DataFrame(Data,columns=['Race_Ethnicity','People_Fully_Vaccinated'])

New_Colors = ['green','blue','purple','brown','teal']
plt.bar()
plt.title()
plt.xlabel()
plt.ylabel()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [70], in <cell line: 7>()
#       2 import pandas as pd
#       4 Data = {'Race_Ethnicity': ['White','Black','Hispanic','Asian or Pacific Islander','American Indian or Alaska Native'],
#       5         'People_Fully_Vaccinated': [34579296,1498047,11829492,17689531,569662,97875147,3975499]
#       6        }
# ----> 7 df = pd.DataFrame(Data,columns=['Race_Ethnicity','People_Fully_Vaccinated'])
#       9 New_Colors = ['green','blue','purple','brown','teal']
#      10 plt.bar()
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
 
# Read CSV into pandas
data = pd.read_csv(r"cars.csv")
data.head()
df = pd.DataFrame(data)
 
name = df['car'].head(12)
price = df['price'].head(12)
 
# Figure Size
fig = plt.figure(figsize =(10, 7))
 
# Horizontal Bar Plot
plt.bar(name[0:10], price[0:10])
 
# Show Plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [71], in <cell line: 5>()
#       2 from matplotlib import pyplot as plt
#       4 # Read CSV into pandas
# ----> 5 data = pd.read_csv(r"cars.csv")
#       6 data.head()
#       7 df = pd.DataFrame(data)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
def plot_pie(White, Black , Hispanic , Asian or Pacific Islander , American Indian or Alaska Native,title):
    labels = ['White','Black','Hispanic','Asian or Pacific Islander','American Indian or Alaska Native']
    sizes = [White, Black , Hispanic , Asian or Pacific Islander , American Indian or Alaska Native]
    color= ['#66b3ff','green','red','yellow','black']
    explode = []

    for i in labels:
        explode.append(0.05)
    
    plt.figure(figsize= (15,6))
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=9, explode =explode,colors = color)
    centre_circle = plt.Circle((0,0),0.70,fc='white')

    fig = plt.gcf()
    fig.gca().add_artist(centre_circle)
    plt.title(title +  'COVID-19 Cases',fontsize = 20)
    plt.axis('equal')  
    plt.tight_layout()
# Out:
#   Input In [72]
#     def plot_pie(White, Black , Hispanic , Asian or Pacific Islander , American Indian or Alaska Native,title):
#                                                  ^
# SyntaxError: invalid syntax
